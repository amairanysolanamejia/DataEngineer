# %% [markdown]
# # Ingeniería de datos
#  *Amairany solana*

# %% [markdown]
# ## Tipos de datos

# %% [markdown]
# ### Primitivos
#
# Enteros, flotantes, booleanos, hexadecimales, octales, datetime

# %% [markdown]
# ## Estructurados

# %%
from IPython.display import Image
Image('tabla_ejemplo.png')

# %% [markdown]
# ## Semiestructurados

# %%
Image('html_markup_example.png')

# %% [markdown]
# ## No estructurados

# %% [markdown]
# Lorem ipsum dolor sit amet, consectetur adipiscing elit, sed do eiusmod tempor incididunt ut labore et dolore magna aliqua.
#
# Ut enim ad minim veniam, quis nostrud exercitation ullamco laboris nisi ut aliquip ex ea commodo consequat.
#
# Duis aute irure dolor in reprehenderit in voluptate velit esse cillum dolore eu fugiat nulla pariatur.
#
# Excepteur sint occaecat cupidatat non proident, sunt in culpa qui officia deserunt mollit anim id est laborum

# %% [markdown]
# ## Solicitudes a la web

# %%
import requests

response = requests.get('https://www.bancomundial.org/es/home')

#response? #Muestra ayuda sobre "requests"

# %%
print(response.headers['Date'])
#print(response.headers)
#print(response.text) #Muestra el texto de la página
# Out:
# Thu, 18 Mar 2021 15:27:04 GMT

# %% [markdown]
# ## Extracción de información del HTML

# %%
import bs4

soup = bs4.BeautifulSoup(response.text,'html.parser')

print(soup.title.text) #Accedemos al titulo
# Out:
# Portada del Banco Mundial — Desarrollo internacional, datos sobre pobreza.

# %%
print(soup.select('meta[name="keywords"]')) 
# Accedemos al apartado "keywords"
# Out:
# [<meta content="Medio ambiente y recursos naturales, desarrollo del sector privado, Reuniones de Primavera, Reuniones Anuales, Banco Mundial, Agua, pobreza, Grupo del Banco Mundial, Banco Internacional de Reconstrucción y Fomento (BIRF), Estrategias de lucha contra la pobreza, Desigualdad y prosperidad compartida, COVID-19 (coronavirus), Empleo y desarrollo, Género, Desarrollo impulsado por la comunidad, Centro Internacional de Arreglo de Diferencias Relativas a Inversiones (CIADI), Inclusión financiera, Salud, Agricultura y seguridad alimentaria, Cambio climático, Salud maternoinfantil y salud sexual y reproductiva, Presidente del Grupo Banco Mundial, Asociación Internacional de Fomento (AIF)" name="keywords"/>]

# %%
print(soup.select('meta[name="keywords"]')[0]['content'])
# Accedemos al apartado "keywords"
# Out:
# Medio ambiente y recursos naturales, desarrollo del sector privado, Reuniones de Primavera, Reuniones Anuales, Banco Mundial, Agua, pobreza, Grupo del Banco Mundial, Banco Internacional de Reconstrucción y Fomento (BIRF), Estrategias de lucha contra la pobreza, Desigualdad y prosperidad compartida, COVID-19 (coronavirus), Empleo y desarrollo, Género, Desarrollo impulsado por la comunidad, Centro Internacional de Arreglo de Diferencias Relativas a Inversiones (CIADI), Inclusión financiera, Salud, Agricultura y seguridad alimentaria, Cambio climático, Salud maternoinfantil y salud sexual y reproductiva, Presidente del Grupo Banco Mundial, Asociación Internacional de Fomento (AIF)

# %%
# Acceder a una página en internet y obtener el titulo y el enlace de sitios interesantes
response = requests.get('https://www.worldbank.org/en/research') #Accedemos a la página del banco mundial
soup = bs4.BeautifulSoup(response.text, 'html.parser')

research = soup.select('.lp__card_content a')                    #Las investigaciones se encuentran en este apartado del 
                                                                 #html

for item in research:                                            #Muestra en pantalla el título de la investigación
    print('Titulo: {}'.format(item.text))                        #y el enlace de cada una
    print('Enlace: {}'.format(item['href']))
# Out:
# Titulo:
#                     Who on Earth Can Work from Home? A global comparison sheds light on the importance of ICT infrastructure
#
#
# Enlace: https://www.worldbank.org/en/news/feature/2020/10/22/who-on-earth-can-work-from-home-a-global-comparison-sheds-light-on-the-importance-of-ict-infrastructure
# Titulo: Working Paper
# Enlace: https://openknowledge.worldbank.org/handle/10986/34277
# Titulo: COVID-19 eSeminar Video
# Enlace: https://www.worldbank.org/en/events/2020/06/16/labor-market-impacts-of-covid-19
# Titulo:
#                     Tackling the impact of job displacement through public policies
#
#
# Enlace: https://www.worldbank.org/en/news/feature/2020/10/20/tackling-the-impact-of-job-displacement-through-public-policies
# Titulo: Working Paper
# Enlace: https://openknowledge.worldbank.org/bitstream/handle/10986/33720/Causes-and-Impacts-of-Job-Displacements-and-Public-Policy-Responses.pdf?sequence=1&isAllowed=y
# ...

# %%
print(research)                                         # Muestra lo que contiene cada apartado en research
# Out:
# [<a href="https://www.worldbank.org/en/news/feature/2020/10/22/who-on-earth-can-work-from-home-a-global-comparison-sheds-light-on-the-importance-of-ict-infrastructure">
#                     Who on Earth Can Work from Home? A global comparison sheds light on the importance of ICT infrastructure
#
#                 </a>, <a aria-describedby="sr-card-title" href="https://openknowledge.worldbank.org/handle/10986/34277">Working Paper</a>, <a aria-describedby="sr-card-title" href="https://www.worldbank.org/en/events/2020/06/16/labor-market-impacts-of-covid-19">COVID-19 eSeminar Video</a>, <a href="https://www.worldbank.org/en/news/feature/2020/10/20/tackling-the-impact-of-job-displacement-through-public-policies">
#                     Tackling the impact of job displacement through public policies
#
# ...

# %%
# Acceder a una página en internet y obtener el titulo y el enlace de sitios interesantes
response = requests.get('https://www.who.int/es')                #Accedemos a la página de la OMS
soup = bs4.BeautifulSoup(response.text, 'html.parser')

research = soup.select('.arrowed-link a')                        #Las investigaciones se encuentran en este apartado
                                                                 #html

for item in research:                                            #Muestra en pantalla el título de la investigación
    print('Titulo: {}'.format(item.text))                        #y el enlace de cada una
    print('Enlace: {}\n'.format(item['href']))
# Out:
# Titulo: Preguntas y respuestas sobre la enfermedad por coronavirus (COVID-19)
# Enlace: /es/emergencies/diseases/novel-coronavirus-2019/advice-for-public/q-a-coronaviruses
#
# Titulo: Orientaciones para el público
# Enlace: /es/emergencies/diseases/novel-coronavirus-2019/advice-for-public
#
# Titulo: Vacunas contra la COVID-19
# Enlace: /es/emergencies/diseases/novel-coronavirus-2019/covid-19-vaccines
#
# Titulo: COVAX:colaboración para un acceso equitativo mundial a las vacunas
# Enlace: /es/initiatives/act-accelerator/covax
#
# Titulo: Orientaciones técnicas sobre la COVID-19
# Enlace: /es/emergencies/diseases/novel-coronavirus-2019/technical-guidance
#
# Titulo: Consejos para la población acerca de los rumores sobre la COVID-19
# Enlace: /es/emergencies/diseases/novel-coronavirus-2019/advice-for-public/myth-busters

# %%
response = requests.get("https://www.eltiempo.com")     #Accedemos a la página de "El tiempo" y se realiza lo mismo

soup = bs4.BeautifulSoup(response.text, 'html.parser')
news = soup.select('.title-container a')

for item in news:
    print(f"Noticia:{item.text}\nLink: {item['href']}\n")
# Out:
# Noticia:¿Se viene una 'guerra fría' tras el giro de Biden hacia China y Rusia?
# Link: /mundo/eeuu-y-canada/estados-unidos-como-sera-la-relacion-de-biden-con-china-y-rusia-574480
#
# Noticia:Médico que manejaba ebrio atropelló a cinco ciclistas y quiso fugarse
# Link: /colombia/otras-ciudades/cucuta-medico-embriagado-atropello-a-cinco-ciclistas-y-se-fugo-574579
#
# Noticia:Escándalo en Cartagena: Dau se despachó contra su exprimera dama
# Link: /colombia/otras-ciudades/william-dau-revela-actuar-de-cynthia-perez-amador-fuera-de-la-alcaldia-574576
#
# Noticia:¿Por qué ganó el voto en blanco en consulta para rector de la Universidad Nacional?
# Link: /vida/educacion/voto-en-blanco-gana-en-consulta-para-rector-de-la-universidad-nacional-574605
#
# Noticia:Advierten a Saab que si busca defenderse, se debe presentar en EE. UU.
# Link: /unidad-investigativa/alex-saab-le-advierten-que-si-busca-defenderse-se-debe-presentar-en-ee-uu-574531
#
# ...

# %%
print(news)
# Out:
# [<a class="title page-link" href="/mundo/eeuu-y-canada/estados-unidos-como-sera-la-relacion-de-biden-con-china-y-rusia-574480" id="m14610-3-14611">¿Se viene una 'guerra fría' tras el giro de Biden hacia China y Rusia?</a>, <a class="title page-link" href="/colombia/otras-ciudades/cucuta-medico-embriagado-atropello-a-cinco-ciclistas-y-se-fugo-574579" id="m14661-4-14662">Médico que manejaba ebrio atropelló a cinco ciclistas y quiso fugarse</a>, <a class="title page-link" href="/colombia/otras-ciudades/william-dau-revela-actuar-de-cynthia-perez-amador-fuera-de-la-alcaldia-574576" id="m14705-4-14706">Escándalo en Cartagena: Dau se despachó contra su exprimera dama</a>, <a class="title page-link" href="/vida/educacion/voto-en-blanco-gana-en-consulta-para-rector-de-la-universidad-nacional-574605" id="m14742-3-14743" style="width: auto;">¿Por qué ganó el voto en blanco en consulta para rector de la Universidad Nacional?</a>, <a class="title page-link" href="/unidad-investigativa/alex-saab-l
# ...

# %%
#Acceder al tpitulo y al contenido de las investigaciones del Banco Mundial
response2 = requests.get('https://www.worldbank.org/en/news/feature/2020/10/22/who-on-earth-can-work-from-home-a-global-comparison-sheds-light-on-the-importance-of-ict-infrastructure') #Accedemos a la página del banco mundial
soup = bs4.BeautifulSoup(response2.text, 'html.parser')

titulo = soup.select('h1')                    #Las investigaciones se encuentran en este apartado del 
                                                                 #html

contenido = soup.select('.redesign_static_content section p')

for item in titulo:                                            #Muestra en pantalla el título de la investigación
    print('Titulo: {}'.format(item.text))                        #y el enlace de cada una

for item in contenido:                                            #Muestra en pantalla el título de la investigación                       #y el enlace de cada una
    print('\n{}'.format(item.text))
# Out:
# Titulo: Who on Earth Can Work from Home? A global comparison sheds light on the importance of ICT infrastructure
#
# The COVID-19 pandemic is expected to inflict severe pain in labor markets across the globe, and policy makers will need to target support to workers who are hit hardest. To inform such efforts, a recent working paper Who on Earth Can Work from Home presents an estimate of jobs that can be done from home across the globe. What’s new is the emphasis on access to the internet, which has become even more critical during the pandemic. Çağlar Özden, co-author and lead economist in the World Bank’s Development Research Group, unpacks the analysis and explains why it matters.
#
# ...

# %%
#Acceder al tpitulo y al contenido de las investigaciones del Banco Mundial
response2 = requests.get('https://www.worldbank.org/en/events/2020/06/16/labor-market-impacts-of-covid-19') #Accedemos a la página del banco mundial
soup = bs4.BeautifulSoup(response2.text, 'html.parser')

titulo = soup.select('h1')                    #Las investigaciones se encuentran en este apartado del 
                                                                 #html

contenido = soup.select('.redesign_static_content section p')

for item in titulo:                                            #Muestra en pantalla el título de la investigación
    print('Titulo: {}'.format(item.text))                        #y el enlace de cada una

for item in contenido:                                            #Muestra en pantalla el título de la investigación                       #y el enlace de cada una
    print('\n{}'.format(item.text))
# Out:
# Titulo: The Labor Market Impacts of COVID-19
#
# Presentations: Nicholas Bloom | Ed Glaeser | Bob Rijkers | David Autor
#
# In high-, middle-, and low-income countries, the novel coronavirus (COVID-19) outbreak has sparked deep concerns about the effects of the pandemic shock on employment. These concerns are associated primarily with the impact of the shock on labor demand, but tend not to consider its effect on the potential labor force. As those susceptible to infection modify their labor supply decisions to minimize the risk of infection, exposed firms are simultaneously adjusting their labor demand to cope with supply-chain disruptions and the contraction in sales.
#
# ...

# %%
#Acceder al tpitulo y al contenido de las investigaciones del Banco Mundial
response2 = requests.get('https://www.who.int/es/emergencies/diseases/novel-coronavirus-2019/advice-for-public') #Accedemos a la página del banco mundial
soup = bs4.BeautifulSoup(response2.text, 'html.parser')

titulo = soup.select('h1')                    #Las investigaciones se encuentran en este apartado del 
                                                                 #html

contenido = soup.select('.sf-content-block content-block li')

for item in titulo:                                            #Muestra en pantalla el título de la investigación
    print('Titulo: {}'.format(item.text))                        #y el enlace de cada una

for item in contenido:                                            #Muestra en pantalla el título de la investigación                       #y el enlace de cada una
    print('\n{}'.format(item.text))
# Out:
# Titulo: Brote de enfermedad por coronavirus (COVID-19): orientaciones para el público

# %% [markdown]
# ## Configuración de Web Scraper
# **1. Se crean 3 carpetas (config.yaml, common,py, main.py)**
# **2. Se configura config.yaml**
# ```python
# research_sites:
#         bancomundial:
#                 url: https://www.worldbank.org/en/research
#         oms:
#                 url: https://www.who.int/es
# ```
#
# **3. Cargar el archivo (en common.py) para usar la configuración (instalé yaml así 'pip install PyYAML'):**
#
# ```python
# import yaml
#
#
# __config = None
#
#
# def config():
#     global __config
#     if not __config:
#         with open('config.yaml',mode='r') as f:
#                 __config = yaml.load(f)
#
#     return __config
#
# ```
#
# **Nota: si aparece un mensaje de que yaml es obsoleta se susituye la linea "__config = yaml.load(f)"  por " _config = yaml.safe_load(f)"**
#
#
# **4. Modificar main.py**
#
# ```python
# import argparse
# import logging
# logging.basicConfig(level=logging.INFO)
#
# from common import config
#
# logger = logging.getLogger(__name__)
#
# def _research_scraper(research_site_uid):
#     host=config()['research_sites'][research_site_uid]['url']
#
#     logging.info('Beginning scraper for {}'.format(host))
# if __name__ == '__main__':
#     parser = argparse.ArgumentParser()
#
#     research_site_choices = list(config()['research_sites'].keys())
#     parser.add_argument('research_site',
#             help='Site that you want to scrape',
#             type =str,
#             choices=research_site_choices)
#
#     args = parser.parse_args()
#     _research_scraper(args.research_site)
# ```
#
# **5. Comprobar lo realizado**
# ``` shell
# python main.py --help
# python main.py oms
# ```
#
# **6. Crear archivo que almacenará los objetos (research_page_objects.py)**
# ```python
# import requests
#
# from common import config
#
# class HomePage:
#     def __init__(self,research_site_uid,url):
#         self._config =config()['research_sites'][research_site_uid]
#         self._queries = self._config['queries']
#         self._html= None
#
#         self._visit(url)
#
#     def _visit(self, url):
#         response=requests.get(url)
#
#         response.raise_for_status()
#
#         self._html=bs4.BeautifulSoup(response.text, 'html.parser')
# ```
#
# **7. Modificación de las configuraciones**
# ```yaml
# research_sites:
#         bancomundial:
#                 url: https://www.bancomundial.org/es/home
#                 queries:
#                         homepage_article_links : '.lp__card_content a'
#         oms:
#                 url: https://www.who.int/es
#                 queries:
#                         homepage_article_links : '.arrowed-link a'
#
# ```
# **8. Modificación de los objetos en "research_page_objects"**
#
# ```python
# import requests
#
# from common import config
#
# class HomePage:
#     def __init__(self,research_site_uid,url):
#         self._config =config()['research_sites'][research_site_uid]
#         self._queries = self._config['queries']
#         self._html= None
#
#         self._visit(url)
#
#     @property
#     def article_links(self):
#         link_list = []
#         for link in self._select(self._queries['homepage_article_links']):
#             if link and link.has_attr('href'):
#                 link_list.append(link)
#         return set(link['href'] for link in link_list)
#
#     def _visit(self, url):
#         response=requests.get(url)
#
#         response.raise_for_status()
#
#         self._html=bs4.BeautifulSoup(response.text, 'html.parser')
#
# ```
# **9. Modificación del archivo principal (main.py)**
#
# ```python
# import argparse
# import logging
# logging.basicConfig(level=logging.INFO)
#
# import research_page_objects as research
# from common import config
#
# logger = logging.getLogger(__name__)
#
# def _research_scraper(research_site_uid):
#     host=config()['research_sites'][research_site_uid]['url']
#
#     logging.info('Beginning scraper for {}'.format(host))
#     homepage = research.HomePage(research_site_uid, host)
#
#     for link in homepage.article_links:
#         print(link)
#
#
# if __name__ == '__main__':
#     parser = argparse.ArgumentParser()
#
#     research_site_choices = list(config()['research_sites'].keys())
#     parser.add_argument('research_site',
#             help='Site that you want to scrape',
#             type =str,
#             choices=research_site_choices)
#
#     args = parser.parse_args()
#     _research_scraper(args.research_site)
# ```
# **10. Comprobar**
# ```
# python main.py oms
# ```
# Lo que debe mostrar en la terminal los links de la Organización Mundial de la Salud, o en caso de poner "bancomundial" sus respectivos enlaces.

# %%
Image('consulta_bancomundial.png')

# %%
Image('consultasoms.png')

# %% [markdown]
# **10. Implementar el web scrapper obteniendo artículos. Modificar el archivo de configuraciones**
#
# ```yaml
# research_sites:
#         bancomundial:
#                 url: https://www.worldbank.org/en/research
#                 queries:
#                         homepage_article_links : '.lp__card_content a'
#                         article_body: '.redesign_static_content section p'
#                         article_title: 'h1'
#         oms:
#                 url: https://www.who.int/es
#                 queries:
#                         homepage_article_links : '.arrowed-link a'
# ```
# **Nota: Es importante mencionar que cada página tiene una estructura distinta, por lo que es necesario adaptar todos los campos de este archivo "config.yaml" en caso de cambiar o incorporar páginas web.**
#
# **11. Se modifican en archivo main.py**
# ```python
# import argparse
# import logging
# logging.basicConfig(level=logging.INFO)
# import re
#
# from requests.exceptions import HTTPError
# from urllib3.exceptions import MaxRetryError
#
# import research_page_objects as research
# from common import config
#
# logger = logging.getLogger(__name__)
# is_well_formed_link = re.compile(r'^https?://.+/.+$')
# is_root_path = re.compile(r'^/.+$')
#
# def _research_scraper(research_site_uid):
#     host=config()['research_sites'][research_site_uid]['url']
#
#     logging.info('Beginning scraper for {}'.format(host))
#     homepage = research.HomePage(research_site_uid, host)
#
#     articles = []
#     for link in homepage.article_links:
#         article = _fetch_article(research_site_uid, host, link)
#
#         if article:
#             logger.info('Article fetched!!! yeih')
#             articles.append(article)
#             print(article.title)
#         print(len(articles))
#
# def _fetch_article(research_site_uid, host, link):
#     logger.info('Start fetching article at {}'.format(link))
#
#     article = None
#     try:
#             article = research.ArticlePage(research_site_uid, _build_link(host,link))
#     except(HTTPError, MaxRetryError) as e:
#         logger.warning('Error while fetching the article', exc_info = False)
#
#     if article and not article.body:
#         logger.warning('Invalid article, there is no body')
#         return None
#     return article
#
# def _build_link(host, link):
#     if is_well_formed_link.match(link):
#         return link
#     elif is_root_path.match(link):
#         return '{}{}'.format(host, link)
#     else:
#         return '{host}({uri}'.format(host=host,uri=link)
#
# if __name__ == '__main__':
#     parser = argparse.ArgumentParser()
#
#     research_site_choices = list(config()['research_sites'].keys())
#     parser.add_argument('research_site',
#             help='Site that you want to scrape',
#             type =str,
#             choices=research_site_choices)
#
#     args = parser.parse_args()
#     _research_scraper(args.research_site)
# ```
#
# **12. Se modifica el arhcivo de objetos**
#
# ```python
# import bs4
# import requests
#
# from common import config
# class ResearchPage:
#     def __init__(self,research_site_uid,url):
#         self._config =config()['research_sites'][research_site_uid]
#         self._queries = self._config['queries']
#         self._html= None
#         self._visit(url)
#
#     def _select(self, query_string):
#         return self._html.select(query_string)
#
#     def _visit(self, url):
#         response=requests.get(url)
#
#         response.raise_for_status()
#
#         self._html=bs4.BeautifulSoup(response.text, 'html.parser')
#
# class HomePage(ResearchPage):
#     def __init__(self,research_site_uid,url):
#         super().__init__(research_site_uid,url)
#
#
#     @property
#     def article_links(self):
#         link_list = []
#         for link in self._select(self._queries['homepage_article_links']):
#             if link and link.has_attr('href'):
#                 link_list.append(link)
#         return set(link['href'] for link in link_list)
#
#
# class ArticlePage(ResearchPage):
#     def __init__(self, research_site_uid, url):
#         super().__init__(research_site_uid,url)
#
#     @property
#     def body(self):
#         result = self._select(self._queries['article_body'])
#
#         return result[0].text if len(result) else ''
#
#     def title(self):
#         result = self._select(self._queries['article_title'])
#
#         return result[0].text if len(result) else ''
#
# ```
# **13. Se comprueba***
#
# ```
# python main.py oms
# ```

# %%
Image('obtenerarticulos.png')

# %% [markdown]
# **13. Persistiendo la información. Se modifica el archivo main.py**
# ```python
# import argparse
# import csv
# import datetime
# import logging
# logging.basicConfig(level=logging.INFO)
# import re
#
# from requests.exceptions import HTTPError
# from urllib3.exceptions import MaxRetryError
#
# import research_page_objects as research
# from common import config
#
#
# logger = logging.getLogger(__name__)
# is_well_formed_link = re.compile(r'^https?://.+/.+$') # https://example.com/hello
# is_root_path = re.compile(r'^/.+$') # /some-text
#
#
# def _research_scraper(research_site_uid):
#     host = config()['research_sites'][research_site_uid]['url']
#
#     logging.info('Beginning scraper for {}'.format(host))
#     homepage = research.HomePage(research_site_uid, host)
#
#     articles = []
#     for link in homepage.article_links:
#         article = _fetch_article(research_site_uid, host, link)
#
#         if article:
#             logger.info('Article fetched!!')
#             articles.append(article)
#
#
#     _save_articles(research_site_uid, articles)
#
#
# def _save_articles(research_site_uid, articles):
#     now = datetime.datetime.now().strftime('%Y_%m_%d')
#     out_file_name = '{research_site_uid}_{datetime}_articles.csv'.format(
#         research_site_uid=research_site_uid,
#         datetime=now)
#     csv_headers = list(filter(lambda property: not property.startswith('_'), dir(articles[0])))
#
#     with open(out_file_name, mode='w+') as f:
#         writer = csv.writer(f)
#         writer.writerow(csv_headers)
#
#         for article in articles:
#             row = [str(getattr(article, prop)) for prop in csv_headers]
#             writer.writerow(row)
#
#
# def _fetch_article(research_site_uid, host, link):
#     logger.info('Start fetching article at {}'.format(link))
#
#     article = None
#     try:
#         article = research.ArticlePage(research_site_uid, _build_link(host, link))
#     except (HTTPError, MaxRetryError) as e:
#         logger.warning('Error while fechting the article', exc_info=False)
#
#
#     if article and not article.body:
#         logger.warning('Invalid article. There is no body')
#         return None
#
#     return article
#
#
# def _build_link(host, link):
#     if is_well_formed_link.match(link):
#         return link
#     elif is_root_path.match(link):
#         return '{}{}'.format(host, link)
#     else:
#         return '{host}/{uri}'.format(host=host, uri=link)
#
#
# if __name__ == '__main__':
#     parser = argparse.ArgumentParser()
#
#     research_site_choices = list(config()['research_sites'].keys())
#     parser.add_argument('research_site',
#                         help='The research site that you want to scrape',
#                         type=str,
#                         choices=research_site_choices)
#
#     args = parser.parse_args()
#     _research_scraper(args.research_site)
#
# ```

# %%
Image('persistenciadedatos.png')

# %%
Image('bancomundialarticulos.png')

# %% [markdown]
# **En conclusión sólo se debe de modificar el archivo "config.py" con los respectivos enlaces y nombres de las páginas que se desean consulta**
#
# ![Texto](https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQr_-JnDNa4laDjqVt-UBKVJzBMpjcsmf2AiPACTUj5I61IoT1i)
# ![Texto](https://st2.depositphotos.com/1575949/8011/v/950/depositphotos_80117626-stock-illustration-conclusion-red-stamp-text.jpg)

# %% [markdown]
# ## Transformación de datos con PANDAS

# %% [markdown]
# Pandas nos otorga diversas facilidades para el ““domados de datos””. Nos otorga dos estructuras de datos:
#
#     Series: Es un array unidimensional que representa una columna.
#     DataFrame: Es un conjunto de series que forman una tabla. Se pueden acceder a través de indices como una etiqueta(label) o pueden ser posicionales es decir 0 o índice 100. También pueden ser rangos o slices
#
# Estas estructuras de datos no son contenedores de datos. En Pandas las utilizamos para transformar y enriquecer nuestros datos, manipularlos, manejar los faltantes, realizar operaciones aritméticas, combinar diferentes dataframes en uno solo para obtener una nueva tabla (Platzi).

# %% [markdown]
# ### Series
# Series es un vector unidimensional, para poder acceder a esta lista podemos usar posiciones o labels, siendo este último el preferido para manipular las series. Una diferencia importante sobre las listas de Python es que los datos son homogéneos, es decir solo podemos tener un tipo de dato por cada Serie.
#
# Las Series se pueden crear a partir de cualquier secuencia(listas, tuplas, arrays de numpy y diccionarios).
#
# En Python tenemos la filosofía del Duck Typing, si se ve como un pato y hace cuac, a ese animal le llamamos pato, si una serie se comporta una lista, se accede como una lista en principio deberíamos llamarla lista, pero esto no es así.
#
# Una mejor aproximación para inicializar Series es utilizar diccionarios (Platzi).

# %% [markdown]
# ### DataFrame
# DataFrames son simplemente una tabla donde las filas y las columnas tienen etiquetas, se puede construir de diferentes formas pero siempre debemos considerar que la estructura que necesitamos construir para inicializarla tiene que ser bidimensional. Una matriz y puede ser una lista de listas, lista de tuplas, un diccionario de Python u otro DataFrame.
#
# Si solo tenemos una dimensión a eso no le llamamos DataFrame, le llamamos Serie. Cuando utilizamos un diccionario las llaves se convierten en las llaves de la columna.

# %% [markdown]
# Índices y selección
#
# Existen muchas formas de manipular los DataFrames y de seleccionar los elementos que queremos transformar.
#
# * Dictionary like:
# ```python
# df[`col1`]
# df[['col1', 'col3']]
# ```
# * Numpy like:
# iloc = index location
# ```python
# df.iloc[:]
# df.iloc[:,:]
# ```
# * Label based:
# loc = location
# ```python
# df.loc[:]
# df.loc[:,:]
# ```
#
# Existe una gran diferencia en la forma en la que utilizamos estos slices porque varia de la forma tradicional de Python. loc va a incluir el final del que necesitamos.

# %%
# Lectura de los datos
import pandas as pd
bancomundial = pd.read_csv('web_scrapper/bancomundial_2021_03_18_articles.csv')
bancomundial
# Out:
#                                                 body  \
# 0  Presentations: Nicholas Bloom | Ed Glaeser | B...
# 1  \nThe COVID-19 pandemic is exacerbating inequa...
# 2  The COVID-19 pandemic is expected to inflict s...
# 3  The World Bank Group (WBG) and the Government ...
# 4  The rise in joblessness due to the ongoing COV...
#
#                                                title  \
# 0               The Labor Market Impacts of COVID-19
# 1  Chief Economists Panel: Addressing inequality ...
# 2  Who on Earth Can Work from Home? A global comp...
# 3  The World Bank Group Inclusive Growth and Sust...
# 4  Tackling the impact of job displacement throug...
#
#                                                  url
# 0  https://www.worldbank.org/en/events/2020/06/16...
# 1  https://www.worldbank.org/en/news/video/2020/1...
# 2  https://www.worldbank.org/en/news/feature/2020...
# 3  https://www.worldbank.org/en/country/malaysia/...
# 4  https://www.worldbank.org/en/news/feature/2020...

# %%
# indexación y selección
bancomundial['title']
# Out:
# 0                 The Labor Market Impacts of COVID-19
# 1    Chief Economists Panel: Addressing inequality ...
# 2    Who on Earth Can Work from Home? A global comp...
# 3    The World Bank Group Inclusive Growth and Sust...
# 4    Tackling the impact of job displacement throug...
# Name: title, dtype: object

# %%
bancomundial[['title', 'url']] # pasamos una lista de las tupla que queremos
# Out:
#                                                title  \
# 0               The Labor Market Impacts of COVID-19
# 1  Chief Economists Panel: Addressing inequality ...
# 2  Who on Earth Can Work from Home? A global comp...
# 3  The World Bank Group Inclusive Growth and Sust...
# 4  Tackling the impact of job displacement throug...
#
#                                                  url
# 0  https://www.worldbank.org/en/events/2020/06/16...
# 1  https://www.worldbank.org/en/news/video/2020/1...
# 2  https://www.worldbank.org/en/news/feature/2020...
# 3  https://www.worldbank.org/en/country/malaysia/...
# 4  https://www.worldbank.org/en/news/feature/2020...

# %%
# Numpy like
bancomundial.iloc[2:4]
# Out:
#                                                 body  \
# 2  The COVID-19 pandemic is expected to inflict s...
# 3  The World Bank Group (WBG) and the Government ...
#
#                                                title  \
# 2  Who on Earth Can Work from Home? A global comp...
# 3  The World Bank Group Inclusive Growth and Sust...
#
#                                                  url
# 2  https://www.worldbank.org/en/news/feature/2020...
# 3  https://www.worldbank.org/en/country/malaysia/...

# %%
bancomundial.iloc[4]['title']
# Out:
# 'Tackling the impact of job displacement through public policies '

# %%
bancomundial.loc[:, 'body':'title']
# Out:
#                                                 body  \
# 0  Presentations: Nicholas Bloom | Ed Glaeser | B...
# 1  \nThe COVID-19 pandemic is exacerbating inequa...
# 2  The COVID-19 pandemic is expected to inflict s...
# 3  The World Bank Group (WBG) and the Government ...
# 4  The rise in joblessness due to the ongoing COV...
#
#                                                title
# 0               The Labor Market Impacts of COVID-19
# 1  Chief Economists Panel: Addressing inequality ...
# 2  Who on Earth Can Work from Home? A global comp...
# 3  The World Bank Group Inclusive Growth and Sust...
# 4  Tackling the impact of job displacement throug...

# %% [markdown]
# ### Data wrangling
# Data wrangling es una de las actividades más importantes de todos los profesionales de datos. Simplemente es limpiar, transformar y enriquecer el dataset para objetivos posteriores.
#
# Pandas es una de las herramientas más poderosas para realizar este ““domado”” de datos. Recordemos que Pandas trae muchas de sus abstracciones del lenguaje R, pero nos otorga lo mejor de ambos mundos, por eso es tan popular.
#
# Nos permite:
#
#     generar transformaciones con gran facilidad.
#     trabajar rápidamente con datasets grandes
#     detectar y reemplazar faltantes
#     agrupar y resumir nuestros datos
#     visualizar nuestros resultados.

# %%
# 1.-Añadir el id al DataFrame
bancomundial['Research_uid'] = 'bancomundial'
bancomundial
# Out:
#                                                 body  \
# 0  Presentations: Nicholas Bloom | Ed Glaeser | B...
# 1  \nThe COVID-19 pandemic is exacerbating inequa...
# 2  The COVID-19 pandemic is expected to inflict s...
# 3  The World Bank Group (WBG) and the Government ...
# 4  The rise in joblessness due to the ongoing COV...
#
#                                                title  \
# 0               The Labor Market Impacts of COVID-19
# 1  Chief Economists Panel: Addressing inequality ...
# 2  Who on Earth Can Work from Home? A global comp...
# 3  The World Bank Group Inclusive Growth and Sust...
# 4  Tackling the impact of job displacement throug...
#
#                                                  url  Research_uid
# 0  https://www.worldbank.org/en/events/2020/06/16...  bancomundial
# 1  https://www.worldbank.org/en/news/video/2020/1...  bancomundial
# 2  https://www.worldbank.org/en/news/feature/2020...  bancomundial
# ...

# %%
#2.- obtener el host
from urllib.parse import urlparse

bancomundial['host'] = bancomundial['url'].apply(lambda url: urlparse(url).netloc)
bancomundial
# Out:
#                                                 body  \
# 0  Presentations: Nicholas Bloom | Ed Glaeser | B...
# 1  \nThe COVID-19 pandemic is exacerbating inequa...
# 2  The COVID-19 pandemic is expected to inflict s...
# 3  The World Bank Group (WBG) and the Government ...
# 4  The rise in joblessness due to the ongoing COV...
#
#                                                title  \
# 0               The Labor Market Impacts of COVID-19
# 1  Chief Economists Panel: Addressing inequality ...
# 2  Who on Earth Can Work from Home? A global comp...
# 3  The World Bank Group Inclusive Growth and Sust...
# 4  Tackling the impact of job displacement throug...
#
#                                                  url  Research_uid  \
# 0  https://www.worldbank.org/en/events/2020/06/16...  bancomundial
# 1  https://www.worldbank.org/en/news/video/2020/1...  bancomundial
# 2  https://www.worldbank.org/en/news/feature/2020...  bancomundial
# ...

# %%
bancomundial['host'].value_counts() 
#cuenta la frecuencia de cadah host
# Out:
# www.worldbank.org    5
# Name: host, dtype: int64

# %% [markdown]
# ### Automatización para obtener datos limpios con un script (Parte I)
# ```python
# import argparse
# import logging
# logging.basicConfig(level=logging.INFO)
# from urllib.parse import urlparse
#
#
# import pandas as pd
#
#
# logger = logging.getLogger(__name__)
#
#
# def main(filename):
#     logger.info('Starting cleaning process')
#
#     df = _read_data(filename)
#     newspaper_uid = _extract_newspaper_uid(filename)
#     df = _add_newspaper_uid_column(df, newspaper_uid)
#     df = _extract_host(df)
#
#     return df
#
#
# def _read_data(filename):
#     logger.info('Reading file {}'.format(filename))
#
#     return pd.read_csv(filename)
#
#
# def _extract_newspaper_uid(filename):
#     logger.info('Extracting newspaper uid')
#     newspaper_uid = filename.split('_')[0]
#
#     logger.info('Newspaper uid detected: {}'.format(newspaper_uid))
#     return newspaper_uid
#
#
# def _add_newspaper_uid_column(df, newspaper_uid):
#     logger.info('Filling newspaper_uid column with {}'.format(newspaper_uid))
#     df['newspaper_uid'] = newspaper_uid
#
#     return df
#
#
# def _extract_host(df):
#     logger.info('Extracting host from urls')
#     df['host'] = df['url'].apply(lambda url: urlparse(url).netloc)
#
#     return df
#
#
# if __name__ == '__main__':
#     parser = argparse.ArgumentParser()
#     parser.add_argument('filename',
#                         help='The path to the dirty data',
#                         type=str)
#
#     args = parser.parse_args()
#
#     df = main(args.filename)
#     print(df)
# ```
# Se prueba el código en la terminal con la siguiente línea
# ```shell
# python research_recipe.py bancomundial_2021_03_18_articles.csv
# ```

# %%
Image('recipe.png')

# %% [markdown]
# ### Trabajar con datos faltantes
#
# Los datos faltantes representan un verdadero problema sobre todo cuando estamos realizando agregaciones. Imagina que tenemos datos faltantes y los llenamos con 0, pero eso haría que la distribución de datos se modificaría radicalmente. Podemos eliminar los registros, pero la fuerza de nuestras conclusiones se debilita.
#
# Pandas nos otorga varias funcionalidades para identificarlas y para trabajar con ellas. Existe el concepto que se llama NaN, cuando existe un dato faltante simplemente se rellena con un NaN y en ese momento podemos preguntar cuáles son los datos faltantes con .isna().
#
#     notna() para preguntar dónde hay datos completos.
#     dropna() para eliminar el registro.
#
# Para reemplazar:
#
#     fillna() donde le damos un dato centinela
#     ffill() donde utiliza el último valor.

# %%
# utilizando los datos recolectados de el periódico El Universal

el_universal = pd.read_csv('web_scrapper/eluniversal_2021_03_18_articles.csv')
el_universal
el_universal['host'] = el_universal['url'].apply(lambda url: urlparse(url).netloc)
el_universal
# Out:
#                                                  body  title  \
# 0   \nHabía un coche en llamas y a un lado dos cue...    NaN
# 1   \nA pesar de que el pase a la final es suficie...    NaN
# 2   \n\nLa contingencia sanitaria fue motor de var...    NaN
# 3   \nEl Sistema de Transporte Colectivo (STC) Met...    NaN
# 4   \nEs curioso, aún existen muchos que apuestan ...    NaN
# 5   \nAl parecer, en la Secretaría de Desarrollo A...    NaN
# 6   \nNallely Gutiérrez Gijón militante del Partid...    NaN
# 7   \nPrólogo 1:\n¿Y las vacunas, apá? ¿No que par...    NaN
# 8   \nEste miércoles se registró un accidente de t...    NaN
# 9   \n\nCon creciente insistencia circula el argum...    NaN
# 10  \nJaime Lozano, entrenador de la Selección Mex...    NaN
# 11  \nEn un oficio que firmó en julio pasado, el s...    NaN
# 12  \n\nLas pruebas que se aplican en los principa...    NaN
# 13  \nLa intención era una: anotarse como “logro d...    NaN
# ...

# %%
el_universal['host'].value_counts() 
#cuenta la frecuencia de cadah host
# Out:
# www.eluniversal.com.mx    23
# Name: host, dtype: int64

# %%
#3.- Rellenar datos faltantes
missing_titles_mask = el_universal['title'].isna()
missing_titles_mask #muestra una serie d elos datos faltantes
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
# 5     True
# 6     True
# 7     True
# 8     True
# 9     True
# 10    True
# 11    True
# 12    True
# 13    True
# 14    True
# 15    True
# 16    True
# 17    True
# 18    True
# 19    True
# 20    True
# 21    True
# 22    True
# Name: title, dtype: bool

# %%
#seleccionamos los datos donde faltan, le decimos que nos muestre la url
el_universal[missing_titles_mask]['url'].str.extract(r'(?P<missing_titles>[^/]+)$')
#buscamos el útlimo pedazo, diagonal adicional 1 o más veces, nombranos al grupo como "missing titles"
# Out:
#                                        missing_titles
# 0          droga-y-ejecuciones-en-la-ciudad-de-mexico
# 1   la-seleccion-mexicana-sub-23-quiere-dominar-el...
# 2                   capturan-instantes-de-la-pandemia
# 3   metro-que-sabemos-sobre-el-cierre-de-estacione...
# 4                                       ser-ciudadano
# 5         y-la-austeridad-republicana-don-roman-meyer
# 6   piden-uif-investigar-cuentas-de-israel-betanzo...
# 7   carta-dirigida-rocio-nahle-hagale-un-favor-mex...
# 8   medico-ebrio-intenta-fugarse-luego-de-atropell...
# 9                           estados-unidos-al-rescate
# 10  seleccion-mexicana-sub-23-debe-mejorar-pesar-d...
# 11  gatell-ordena-medicos-no-hacerse-segunda-prueb...
# 12       sin-controles-pruebas-de-covid-para-viajeros
# 13                  los-acuerdos-con-romero-deschamps
# 14          urge-el-pago-por-rendimiento-en-el-futbol
# 15         4t-y-pemex-gestionan-salvavidas-financiero
# ...

# %%
el_universal['url'][0]
# Out:
# 'http://www.eluniversal.com.mx/opinion/hector-de-mauleon/droga-y-ejecuciones-en-la-ciudad-de-mexico'

# %%
#queremos eliminar los guiones
missing_titles =(el_universal[missing_titles_mask]['url']
                .str.extract(r'(?P<missing_titles>[^/]+)$')
                .applymap(lambda title: title.split('-'))
                .applymap(lambda title_word_list: ' '.join((title_word_list))))
# apllymap nos permite generar un mapa de un valor a otro
missing_titles
# Out:
#                                        missing_titles
# 0          droga y ejecuciones en la ciudad de mexico
# 1   la seleccion mexicana sub 23 quiere dominar el...
# 2                   capturan instantes de la pandemia
# 3   metro que sabemos sobre el cierre de estacione...
# 4                                       ser ciudadano
# 5         y la austeridad republicana don roman meyer
# 6   piden uif investigar cuentas de israel betanzo...
# 7   carta dirigida rocio nahle hagale un favor mex...
# 8   medico ebrio intenta fugarse luego de atropell...
# 9                           estados unidos al rescate
# 10  seleccion mexicana sub 23 debe mejorar pesar d...
# 11  gatell ordena medicos no hacerse segunda prueb...
# 12       sin controles pruebas de covid para viajeros
# 13                  los acuerdos con romero deschamps
# 14          urge el pago por rendimiento en el futbol
# 15         4t y pemex gestionan salvavidas financiero
# ...

# %% [markdown]
# ### Automatización para obtener datos limpios con un script (Parte II)
#
# Se modifica el archivo research_recipe:
# ```python
# import argparse
# import logging
# logging.basicConfig(level=logging.INFO)
# from urllib.parse import urlparse
#
#
# import pandas as pd
#
#
# logger = logging.getLogger(__name__)
#
#
# def main(filename):
#     logger.info('Starting cleaning process')
#
#     df = _read_data(filename)
#     newspaper_uid = _extract_newspaper_uid(filename)
#     df = _add_newspaper_uid_column(df, newspaper_uid)
#     df = _extract_host(df)
#     df = _fill_missing_titles(df)
#
#     return df
#
#
# def _read_data(filename):
#     logger.info('Reading file {}'.format(filename))
#
#     return pd.read_csv(filename)
#
#
# def _extract_newspaper_uid(filename):
#     logger.info('Extracting newspaper uid')
#     newspaper_uid = filename.split('_')[0]
#
#     logger.info('Newspaper uid detected: {}'.format(newspaper_uid))
#     return newspaper_uid
#
#
# def _add_newspaper_uid_column(df, newspaper_uid):
#     logger.info('Filling newspaper_uid column with {}'.format(newspaper_uid))
#     df['newspaper_uid'] = newspaper_uid
#
#     return df
#
#
# def _extract_host(df):
#     logger.info('Extracting host from urls')
#     df['host'] = df['url'].apply(lambda url: urlparse(url).netloc)
#
#     return df
#
# def _fill_missing_titles(df):
#     logger.info('Filling missing titles')
#     missing_titles_mask = df['title'].isna()
#     missing_titles = (df[missing_titles_mask]['url']
#                         .str.extract(r'(?P<missing_titles>[^/]+)$')
#                         .applymap(lambda title: title.split('-'))
#                         .applymap(lambda title_word_list: ' '.join(title_word_list))
#                      )
#
#     df.loc[missing_titles_mask, 'title'] = missing_titles.loc[:, 'missing_titles']
#
#     return df
#
# if __name__ == '__main__':
#     parser = argparse.ArgumentParser()
#     parser.add_argument('filename',
#                         help='The path to the dirty data',
#                         type=str)
#
#     args = parser.parse_args()
#
#     df = main(args.filename)
#     print(df)
#
# ```
# Se prueba el código en la terminal con la siguiente línea
# ```shell
# python research_recipe.py bancomundial_2021_03_18_articles.csv
# ```

# %%
el_universal['title'] = missing_titles
el_universal
# Out:
#                                                  body  \
# 0   \nHabía un coche en llamas y a un lado dos cue...
# 1   \nA pesar de que el pase a la final es suficie...
# 2   \n\nLa contingencia sanitaria fue motor de var...
# 3   \nEl Sistema de Transporte Colectivo (STC) Met...
# 4   \nEs curioso, aún existen muchos que apuestan ...
# 5   \nAl parecer, en la Secretaría de Desarrollo A...
# 6   \nNallely Gutiérrez Gijón militante del Partid...
# 7   \nPrólogo 1:\n¿Y las vacunas, apá? ¿No que par...
# 8   \nEste miércoles se registró un accidente de t...
# 9   \n\nCon creciente insistencia circula el argum...
# 10  \nJaime Lozano, entrenador de la Selección Mex...
# 11  \nEn un oficio que firmó en julio pasado, el s...
# 12  \n\nLas pruebas que se aplican en los principa...
# 13  \nLa intención era una: anotarse como “logro d...
# 14  \nSi además de las indisciplinas, que ya le co...
# 15  \n\nPetróleos Mexicanos (Pemex) gestiona un sa...
# ...

# %%
# 4.- Limpieza, añadiendo uid a las filas
import hashlib
#axis 1 filas, axis 0 columnas
uids = (el_universal
        .apply(lambda row: hashlib.md5(bytes(row['url'].encode())), axis =1)
        .apply(lambda hash_object: hash_object.hexdigest())
        )
el_universal['uid']= uids
el_universal.set_index('uid',inplace=True)

el_universal
#esto nos da los hashes de cada una de las urls
# Out:
#                                                                                body  \
# uid
# 846f5c7df25a92deb57e1fdc959c1c62  \nHabía un coche en llamas y a un lado dos cue...
# 3d2cbf0b241b5b6f4ac002c18523e7a5  \nA pesar de que el pase a la final es suficie...
# 0dcb4f6a110230b8412a8c4234597eef  \n\nLa contingencia sanitaria fue motor de var...
# 1e9b511cfc461d71bce1b657469d0d66  \nEl Sistema de Transporte Colectivo (STC) Met...
# 0abd296c1486b92334ec2f73aa428920  \nEs curioso, aún existen muchos que apuestan ...
# 5475cdefe9b9aa64bbe30e61b89c499e  \nAl parecer, en la Secretaría de Desarrollo A...
# aa593a204eb0eadfe56239ef46222c05  \nNallely Gutiérrez Gijón militante del Partid...
# e0040fa4e3d7ba9ace809d34e31641ef  \nPrólogo 1:\n¿Y las vacunas, apá? ¿No que par...
# 1e88cdf09d4a1d43c8d262f17456fe91  \nEste miércoles se registró un accidente de t...
# a67b3bac332fb3f8f9cf744a5a8c68fb  \n\nCon creciente insistencia circula el argum...
# ...

# %%
#eliminar los saltos de linea en el cuerpo de los artículos
stripped_body = (el_universal
                 .apply(lambda row: row['body'],axis=1) #modificamso cada row
                 .apply(lambda body: list(body)) #convierte el body en una lista de letras
                 .apply(lambda letters: list(map(lambda letter: letter.replace('\n',''), letters)))
                 .apply(lambda letters: ''.join(letters))
                )
stripped_body
# Out:
# uid
# 846f5c7df25a92deb57e1fdc959c1c62    Había un coche en llamas y a un lado dos cuerp...
# 3d2cbf0b241b5b6f4ac002c18523e7a5    A pesar de que el pase a la final es suficient...
# 0dcb4f6a110230b8412a8c4234597eef    La contingencia sanitaria fue motor de varias ...
# 1e9b511cfc461d71bce1b657469d0d66    El Sistema de Transporte Colectivo (STC) Metro...
# 0abd296c1486b92334ec2f73aa428920    Es curioso, aún existen muchos que apuestan a ...
# 5475cdefe9b9aa64bbe30e61b89c499e    Al parecer, en la Secretaría de Desarrollo Agr...
# aa593a204eb0eadfe56239ef46222c05    Nallely Gutiérrez Gijón militante del Partido ...
# e0040fa4e3d7ba9ace809d34e31641ef    Prólogo 1:¿Y las vacunas, apá? ¿No que para es...
# 1e88cdf09d4a1d43c8d262f17456fe91    Este miércoles se registró un accidente de trá...
# a67b3bac332fb3f8f9cf744a5a8c68fb    Con creciente insistencia circula el argumento...
# a4fad4fa43a0b7ec6f2c5ae13838444d    Jaime Lozano, entrenador de la Selección Mexic...
# ...

# %% [markdown]
# ### Automatización para obtener datos limpios con un script (Parte III)
#
# ```python
# import argparse
# import hashlib
# import logging
# logging.basicConfig(level=logging.INFO)
# from urllib.parse import urlparse
#
#
# import pandas as pd
#
#
# logger = logging.getLogger(__name__)
#
#
# def main(filename):
#     logger.info('Starting cleaning process')
#
#     df = _read_data(filename)
#     newspaper_uid = _extract_newspaper_uid(filename)
#     df = _add_newspaper_uid_column(df, newspaper_uid)
#     df = _extract_host(df)
#     df = _fill_missing_titles(df)
#     df = _generate_uids_for_rows(df)
#     df = _remove_new_lines_from_body(df)
#
#     return df
#
#
# def _read_data(filename):
#     logger.info('Reading file {}'.format(filename))
#
#     return pd.read_csv(filename)
#
#
# def _extract_newspaper_uid(filename):
#     logger.info('Extracting newspaper uid')
#     newspaper_uid = filename.split('_')[0]
#
#     logger.info('Newspaper uid detected: {}'.format(newspaper_uid))
#     return newspaper_uid
#
#
# def _add_newspaper_uid_column(df, newspaper_uid):
#     logger.info('Filling newspaper_uid column with {}'.format(newspaper_uid))
#     df['newspaper_uid'] = newspaper_uid
#
#     return df
#
#
# def _extract_host(df):
#     logger.info('Extracting host from urls')
#     df['host'] = df['url'].apply(lambda url: urlparse(url).netloc)
#
#     return df
#
# def _fill_missing_titles(df):
#     logger.info('Filling missing titles')
#     missing_titles_mask = df['title'].isna()
#     missing_titles = (df[missing_titles_mask]['url']
#                         .str.extract(r'(?P<missing_titles>[^/]+)$')
#                         .applymap(lambda title: title.split('-'))
#                         .applymap(lambda title_word_list: ' '.join(title_word_list))
#                      )
#
#     df.loc[missing_titles_mask, 'title'] = missing_titles.loc[:, 'missing_titles']
#
#     return df
#
# def _generate_uids_for_rows(df):
#     logger.info('Generating uids for each row')
#     uids = (df
#             .apply(lambda row: hashlib.md5(bytes(row['url'].encode())), axis=1)
#             .apply(lambda hash_object: hash_object.hexdigest())
#             )
#
#     df['uid'] = uids
#
#     return df.set_index('uid')
#
# def _remove_new_lines_from_body(df):
#     logger.info('Remove new lines from body')
#
#     stripped_body = (df
#                      .apply(lambda row: row['body'], axis=1)
#                      .apply(lambda body: list(body))
#                      .apply(lambda letters: list(map(lambda letter: letter.replace('\n', ' '), letters)))
#                      .apply(lambda letters: list(map(lambda letter: letter.replace('\r', ' '), letters)))
#                      .apply(lambda letters: ''.join(letters))
#                     )
#
#     df['body'] = stripped_body
#
#     return df
#
# if __name__ == '__main__':
#     parser = argparse.ArgumentParser()
#     parser.add_argument('filename',
#                         help='The path to the dirty data',
#                         type=str)
#
#     args = parser.parse_args()
#
#     df = main(args.filename)
#     print(df)
# ```

# %%
# otra manera mucho más sencilla de hacer lo anterior es:
el_universal['body'] = el_universal.apply(lambda row: row['body'].replace('\n', ''), axis=1)
el_universal['body']
# Out:
# uid
# 846f5c7df25a92deb57e1fdc959c1c62    Había un coche en llamas y a un lado dos cuerp...
# 3d2cbf0b241b5b6f4ac002c18523e7a5    A pesar de que el pase a la final es suficient...
# 0dcb4f6a110230b8412a8c4234597eef    La contingencia sanitaria fue motor de varias ...
# 1e9b511cfc461d71bce1b657469d0d66    El Sistema de Transporte Colectivo (STC) Metro...
# 0abd296c1486b92334ec2f73aa428920    Es curioso, aún existen muchos que apuestan a ...
# 5475cdefe9b9aa64bbe30e61b89c499e    Al parecer, en la Secretaría de Desarrollo Agr...
# aa593a204eb0eadfe56239ef46222c05    Nallely Gutiérrez Gijón militante del Partido ...
# e0040fa4e3d7ba9ace809d34e31641ef    Prólogo 1:¿Y las vacunas, apá? ¿No que para es...
# 1e88cdf09d4a1d43c8d262f17456fe91    Este miércoles se registró un accidente de trá...
# a67b3bac332fb3f8f9cf744a5a8c68fb    Con creciente insistencia circula el argumento...
# a4fad4fa43a0b7ec6f2c5ae13838444d    Jaime Lozano, entrenador de la Selección Mexic...
# ...

# %% [markdown]
# ### Enriquecimiento de los datos
#
# Podemos enriquecer nuestra tabla con información adicional, un poco de información numérica para realizar análisis posterior.
#
# Usaremos nltk es una librería dentro del stack de Ciencia de Datos de Python que nos va a permitir tokenizar, separar palabras dentro del título y nos permitirá contar la frecuencia de cuántas palabras existen en nuestro título y body

# %%
#!pip install nltk #descomentar si no tienes instalado
# Out:
# ...
#      |████████████████████████████████| 1.4 MB 442 kB/s eta 0:00:01     |███▉                            | 174 kB 671 kB/s eta 0:00:02
# ...
#      |████████████████████████████████| 82 kB 70 kB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 303 kB 375 kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 721 kB 209 kB/s eta 0:00:01     |█████████▌                      | 215 kB 364 kB/s eta 0:00:02
# ...
#      |████████████████████████████████| 74 kB 231 kB/s eta 0:00:01
# Using legacy 'setup.py install' for nltk, since package 'wheel' is not installed.
# ...
#     Running setup.py install for nltk ... done
# ...

# %%
#si nunca la has utilizado, descomenta lo siguiente
#nltk.download('punkt')
#nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /home/solana/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/solana/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
#tokenizar el título y el body
import nltk
from nltk.corpus import stopwords
#stopgords son palabras sin imporancia

stop_words = set(stopwords.words('spanish'))

def tokenize_column(df,column_name):
    return(df
          .dropna()
          .apply(lambda row: nltk.word_tokenize(row[column_name]), axis = 1)
          .apply(lambda tokens: list(filter(lambda token: token.isalpha(), tokens)))
          .apply(lambda tokens: list(map(lambda token: token.lower(), tokens)))
          .apply(lambda word_list: list(filter(lambda word: word not in stop_words, word_list)))
          .apply(lambda valid_word_list: len(valid_word_list))
            )

el_universal['n_tokens_body'] = tokenize_column(el_universal, 'body') #se puede realizar lo mismo en el body
el_universal['n_tokens_title'] = tokenize_column(el_universal, 'title') #se puede realizar lo mismo en el title

el_universal
# Out:
#                                                                                body  \
# uid
# 846f5c7df25a92deb57e1fdc959c1c62  Había un coche en llamas y a un lado dos cuerp...
# 3d2cbf0b241b5b6f4ac002c18523e7a5  A pesar de que el pase a la final es suficient...
# 0dcb4f6a110230b8412a8c4234597eef  La contingencia sanitaria fue motor de varias ...
# 1e9b511cfc461d71bce1b657469d0d66  El Sistema de Transporte Colectivo (STC) Metro...
# 0abd296c1486b92334ec2f73aa428920  Es curioso, aún existen muchos que apuestan a ...
# 5475cdefe9b9aa64bbe30e61b89c499e  Al parecer, en la Secretaría de Desarrollo Agr...
# aa593a204eb0eadfe56239ef46222c05  Nallely Gutiérrez Gijón militante del Partido ...
# e0040fa4e3d7ba9ace809d34e31641ef  Prólogo 1:¿Y las vacunas, apá? ¿No que para es...
# 1e88cdf09d4a1d43c8d262f17456fe91  Este miércoles se registró un accidente de trá...
# a67b3bac332fb3f8f9cf744a5a8c68fb  Con creciente insistencia circula el argumento...
# ...

# %% [markdown]
# ### Automatización para obtener datos limpios con un script (Parte IV)
# ```python
# import argparse
# import hashlib
# import logging
# logging.basicConfig(level=logging.INFO)
# from urllib.parse import urlparse
#
# import nltk
# from nltk.corpus import stopwords
# stop_words = set(stopwords.words('spanish'))
#
# import pandas as pd
#
#
# logger = logging.getLogger(__name__)
#
#
# def main(filename):
#     logger.info('Starting cleaning process')
#
#     df = _read_data(filename)
#     newspaper_uid = _extract_newspaper_uid(filename)
#     df = _add_newspaper_uid_column(df, newspaper_uid)
#     df = _extract_host(df)
#     df = _fill_missing_titles(df)
#     df = _generate_uids_for_rows(df)
#     df = _remove_new_lines_from_body(df)
#     df = _tokenize_column(df, 'title')
#     df = _tokenize_column(df, 'body')
#
#     return df
#
#
# def _read_data(filename):
#     logger.info('Reading file {}'.format(filename))
#
#     return pd.read_csv(filename)
#
#
# def _extract_newspaper_uid(filename):
#     logger.info('Extracting newspaper uid')
#     newspaper_uid = filename.split('_')[0]
#
#     logger.info('Newspaper uid detected: {}'.format(newspaper_uid))
#     return newspaper_uid
#
#
# def _add_newspaper_uid_column(df, newspaper_uid):
#     logger.info('Filling newspaper_uid column with {}'.format(newspaper_uid))
#     df['newspaper_uid'] = newspaper_uid
#
#     return df
#
#
# def _extract_host(df):
#     logger.info('Extracting host from urls')
#     df['host'] = df['url'].apply(lambda url: urlparse(url).netloc)
#
#     return df
#
# def _fill_missing_titles(df):
#     logger.info('Filling missing titles')
#     missing_titles_mask = df['title'].isna()
#     missing_titles = (df[missing_titles_mask]['url']
#                         .str.extract(r'(?P<missing_titles>[^/]+)$')
#                         .applymap(lambda title: title.split('-'))
#                         .applymap(lambda title_word_list: ' '.join(title_word_list))
#                      )
#
#     df.loc[missing_titles_mask, 'title'] = missing_titles.loc[:, 'missing_titles']
#
#     return df
#
# def _generate_uids_for_rows(df):
#     logger.info('Generating uids for each row')
#     uids = (df
#             .apply(lambda row: hashlib.md5(bytes(row['url'].encode())), axis=1)
#             .apply(lambda hash_object: hash_object.hexdigest())
#             )
#
#     df['uid'] = uids
#
#     return df.set_index('uid')
#
# def _remove_new_lines_from_body(df):
#     logger.info('Remove new lines from body')
#
#     stripped_body = (df
#                      .apply(lambda row: row['body'], axis=1)
#                      .apply(lambda body: list(body))
#                      .apply(lambda letters: list(map(lambda letter: letter.replace('\n', ' '), letters)))
#                      .apply(lambda letters: list(map(lambda letter: letter.replace('\r', ' '), letters)))
#                      .apply(lambda letters: ''.join(letters))
#                     )
#
#     df['body'] = stripped_body
#
#     return df
# def _tokenize_column(df, column_name):
#     logger.info('Calculating the number of unique tokens in {}'.format(column_name))
#     stop_words = set(stopwords.words('spanish'))
#
#     n_tokens =  (df
#                  .dropna()
#                  .apply(lambda row: nltk.word_tokenize(row[column_name]), axis=1)
#                  .apply(lambda tokens: list(filter(lambda token: token.isalpha(), tokens)))
#                  .apply(lambda tokens: list(map(lambda token: token.lower(), tokens)))
#                  .apply(lambda word_list: list(filter(lambda word: word not in stop_words, word_list)))
#                  .apply(lambda valid_word_list: len(valid_word_list))
#             )
#
#     df['n_tokens_' + column_name] = n_tokens
#
#     return df
#
#
# if __name__ == '__main__':
#     parser = argparse.ArgumentParser()
#     parser.add_argument('filename',
#                         help='The path to the dirty data',
#                         type=str)
#
#     args = parser.parse_args()
#
#     df = main(args.filename)
#     print(df)
# ```

# %% [markdown]
# ### Valores duplicados
# Estos valores duplicados es importantes identificarlos y removerlos de nuestro datasets para que esos valores no generen un peso no justificado dentro del análisis a realizar dentro de nuestro Pipelines.
#
# Pandas nos otorga la función drop_duplicates para eliminar estos valores duplicados.

# %%
# 8.- Eliminar valores dupplicados
el_universal['title'].value_counts()
# Out:
# eu suspende envio de menores migrantes albergue en texas por falta de condiciones          1
# droga y ejecuciones en la ciudad de mexico                                                 1
# en riesgo candidaturas de mujeres contra la violencia de genero                            1
# capturan instantes de la pandemia                                                          1
# y la austeridad republicana don roman meyer                                                1
# estado sin derecho                                                                         1
# los acuerdos con romero deschamps                                                          1
# caera o no caera la cabeza de vaca                                                         1
# urge el pago por rendimiento en el futbol                                                  1
# 4t y pemex gestionan salvavidas financiero                                                 1
# ...

# %%
# en caso de haber: Eliminación de títulos duplicados con la función drop_duplicates().

#el_universal.drop_duplicates(subset = ['title'], keep = 'first', inplace = True)

# %% [markdown]
# ### Automatización para obtener datos limpios con un script (Parte V) (Ahora sí la última apra este análisis)
# ```python
# import argparse
# import hashlib
# import logging
# logging.basicConfig(level=logging.INFO)
# from urllib.parse import urlparse
#
#
# import pandas as pd
# import nltk
# from nltk.corpus import stopwords
#
#
# logger = logging.getLogger(__name__)
#
#
# def main(filename):
#     logger.info('Starting cleaning process')
#
#     df = _read_data(filename)
#     newspaper_uid = _extract_newspaper_uid(filename)
#     df = _add_newspaper_uid_column(df, newspaper_uid)
#     df = _extract_host(df)
#     df = _fill_missing_titles(df)
#     df = _generate_uids_for_rows(df)
#     df = _remove_new_lines_from_body(df)
#     df = _tokenize_column(df, 'title')
#     df = _tokenize_column(df, 'body')
#     df = _remove_duplicate_entries(df, 'title')
#     df = _drop_rows_with_missing_values(df)
#     _save_data(df, filename)
#
#     return df
#
#
# def _read_data(filename):
#     logger.info('Reading file {}'.format(filename))
#
#     return pd.read_csv(filename)
#
#
# def _extract_newspaper_uid(filename):
#     logger.info('Extracting newspaper uid')
#     newspaper_uid = filename.split('_')[0]
#
#     logger.info('Newspaper uid detected: {}'.format(newspaper_uid))
#     return newspaper_uid
#
#
# def _add_newspaper_uid_column(df, newspaper_uid):
#     logger.info('Filling newspaper_uid column with {}'.format(newspaper_uid))
#     df['newspaper_uid'] = newspaper_uid
#
#     return df
#
#
# def _extract_host(df):
#     logger.info('Extracting host from urls')
#     df['host'] = df['url'].apply(lambda url: urlparse(url).netloc)
#
#     return df
#
#
# def _fill_missing_titles(df):
#     logger.info('Filling missing titles')
#     missing_titles_mask = df['title'].isna()
#
#     missing_titles = (df[missing_titles_mask]['url']
#                         .str.extract(r'(?P<missing_titles>[^/]+)$')
#                         .applymap(lambda title: title.split('-'))
#                         .applymap(lambda title_word_list: ' '.join(title_word_list))
#                       )
#
#     df.loc[missing_titles_mask, 'title'] = missing_titles.loc[:, 'missing_titles']
#
#     return df
#
#
# def _generate_uids_for_rows(df):
#     logger.info('Generating uids for each row')
#     uids = (df
#             .apply(lambda row: hashlib.md5(bytes(row['url'].encode())), axis=1)
#             .apply(lambda hash_object: hash_object.hexdigest())
#             )
#
#     df['uid'] = uids
#
#     return df.set_index('uid')
#
#
# def _remove_new_lines_from_body(df):
#     logger.info('Remove new lines from body')
#
#     stripped_body = (df
#                      .apply(lambda row: row['body'], axis=1)
#                      .apply(lambda body: list(body))
#                      .apply(lambda letters: list(map(lambda letter: letter.replace('\n', ' '), letters)))
#                      .apply(lambda letters: ''.join(letters))
#                     )
#
#     df['body'] = stripped_body
#
#     return df
#
# def _tokenize_column(df, column_name):
#     logger.info('Calculating the number of unique tokens in {}'.format(column_name))
#     stop_words = set(stopwords.words('spanish'))
#
#     n_tokens =  (df
#                  .dropna()
#                  .apply(lambda row: nltk.word_tokenize(row[column_name]), axis=1)
#                  .apply(lambda tokens: list(filter(lambda token: token.isalpha(), tokens)))
#                  .apply(lambda tokens: list(map(lambda token: token.lower(), tokens)))
#                  .apply(lambda word_list: list(filter(lambda word: word not in stop_words, word_list)))
#                  .apply(lambda valid_word_list: len(valid_word_list))
#             )
#
#     df['n_tokens_' + column_name] = n_tokens
#
#     return df
#
#
# def _remove_duplicate_entries(df, column_name):
#     logger.info('Removing duplicate entries')
#     df.drop_duplicates(subset=[column_name], keep='first', inplace=True)
#
#     return df
#
#
# def _drop_rows_with_missing_values(df):
#     logger.info('Dropping rows with missing values')
#     return df.dropna()
#
#
# def _save_data(df, filename):
#     clean_filename = 'clean_{}'.format(filename)
#     logger.info('Saving data at location: {}'.format(clean_filename))
#     df.to_csv(clean_filename)
#
#
# if __name__ == '__main__':
#     parser = argparse.ArgumentParser()
#     parser.add_argument('filename',
#                         help='The path to the dirty data',
#                         type=str)
#
#     args = parser.parse_args()
#
#     df = main(args.filename)
# ```

# %% [markdown]
# ## Visualización de los datos

# %%
clean_eluniversal = pd.read_csv('web_scrapper/clean_eluniversal_2021_03_18_articles.csv')
clean_bancomundial = pd.read_csv('web_scrapper/clean_bancomundial_2021_03_18_articles.csv')

# %%
clean_eluniversal.describe()
# Out:
#        n_tokens_title  n_tokens_body
# count        24.00000      24.000000
# mean          5.50000     318.541667
# std           2.68652     159.228296
# min           1.00000     111.000000
# 25%           4.00000     221.750000
# 50%           5.00000     291.000000
# 75%           7.25000     357.250000
# max          12.00000     716.000000

# %%
clean_bancomundial.describe()
# Out:
#        n_tokens_title  n_tokens_body
# count        5.000000       5.000000
# mean        10.200000      63.200000
# std          4.549725      33.877721
# min          5.000000       9.000000
# 25%          8.000000      54.000000
# 50%          9.000000      75.000000
# 75%         12.000000      82.000000
# max         17.000000      96.000000

# %%
clean_bancomundial.loc[clean_bancomundial['n_tokens_title']==5]
# Out:
#                                 uid  \
# 2  2e0df4daf7f228ba2f909bf8ebc4e546
#
#                                                 body  \
# 2  Presentations: Nicholas Bloom | Ed Glaeser | B...
#
#                                   title  \
# 2  The Labor Market Impacts of COVID-19
#
#                                                  url newspaper_uid  \
# 2  https://www.worldbank.org/en/events/2020/06/16...  bancomundial
#
#                 host  n_tokens_title  n_tokens_body
# 2  www.worldbank.org               5              9

# %%
# %matplotlib inline

# %%
clean_bancomundial['n_tokens_title'].plot(style='k.')
clean_eluniversal['n_tokens_title'].plot(style='r.')

# %%
clean_bancomundial['n_tokens_body'].plot(style='k.')
clean_eluniversal['n_tokens_body'].plot(style='r.')

# %%
all_research = pd.concat([clean_bancomundial, clean_eluniversal])
grouped = all_research.groupby('newspaper_uid')
grouped.hist()
# Out:
# newspaper_uid
# bancomundial    [[AxesSubplot(0.125,0.125;0.336957x0.755), Axe...
# eluniversal     [[AxesSubplot(0.125,0.125;0.336957x0.755), Axe...
# dtype: object

# %%
grouped['n_tokens_body'].agg(['min', 'mean','max'])
# Out:
#                min        mean  max
# newspaper_uid
# bancomundial     9   63.200000   96
# eluniversal    111  318.541667  716

# %%
grouped.plot()
# Out:
# newspaper_uid
# bancomundial    AxesSubplot(0.125,0.125;0.775x0.755)
# eluniversal     AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %% [markdown]
# ## Introducción a los sistemas de datos
#
# Los sistemas de datos vienen en muchos sabores y colores, SQL, NoSQL, especializados en procesamiento en bloque, chorro y streaming. Este tipo de sistema nos permite realizar queries sofisticadas y compartir nuestro trabajo con otros miembros del equipo.
#
#     Procesamiento de bloque: Estamos hablando de datos históricos, qué sucedió ayer, en el trimestre pasado, cuáles fueron las ventas del año anterior o de los últimos cinco años. Nos permite realizar el procesamiento de manera eficiente.
#
#     Procesamiento en chorro: Significa que estamos procesando los datos conforme van llegando, las transformaciones se realizan en tiempo real, Este tipo de sistema nos sirven para cuando queremos realizar decisiones en donde la importancia del tiempo es fundamental.
#
# El criterio principal a tener en cuenta: El tiempo que tienes. Si bien los sistemas open source son gratis, para poderlos implementar necesitas tener conocimientos de cloud, debes poder saber trabajar y mantener máquinas.
#
# SQL vs NoSQL
#
#     La discusión más relevante en el mundo de las aplicaciones web y móvil, donde dependiendo de la aplicación, la decisión puede ser fundamental para el crecimiento de la app.
#     La verdad es que para los profesionales de los datos, especialmente los profesionales de los datos. Es necesario saber ambos.

# %% [markdown]
# ## Referencias
#
# * Aroesti, D. (S.A.) Curso de Ingeniería de Datos con Python. Recuperado de: https://platzi.com/cursos/ingenieria-datos/
